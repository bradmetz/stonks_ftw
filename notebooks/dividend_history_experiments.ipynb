# %% [markdown]
# # Logic check for weekly report downloads dividendhistory.org

# %% [markdown]
# this notebook is used to figure the flow for creating an automated downloader for dividendhistory.org
#
# Canadian exchanges (the day in the link is the friday)
#
# https://dividendhistory.org/reports/CAN/2020-02-28-report.htm
#
# US exchanges
#
# https://dividendhistory.org/reports/USA/2020-02-28-report.htm
#
# a simple pandas datareader should be sufficient

# %%
import pandas as pd

dfs = pd.read_html('https://dividendhistory.org/reports/CAN/2020-02-28-report.htm')

print(dfs)
# Out:
# [    DividendHistory.org  Report (beta)&nbsp&nbsp&nbsp&nbsp 2020-02-28 / CAN  \
#                                                                      Symbol
# 0                                      Basic Materials
# 1                                                  NGT
# 2                                                  ABX
# 3                                                  NTR
# 4                                                  FNV
# ..                                                 ...
# 385                                              CUP.U
# 386                                                ATP
# 387                                                PIF
# 388                                                 JE
# 389                                                CFY
#
#                                                                      \
#                              Name            Price              Yld
# ...
