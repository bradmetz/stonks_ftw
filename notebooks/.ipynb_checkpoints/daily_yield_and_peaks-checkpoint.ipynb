# %% [markdown]
# Coding for divdidend yield, peak detection, and graphing

# %%
import pandas as pd

dfs = pd.read_csv(f'.././datasets/tsx/DH_div_history_T.csv', keep_default_na=False)

dfs2 = pd.read_csv(f'.././datasets/price_history/yahoo_price_history_T.TO.csv')

# %%
print(dfs)
# Out:
#    Ex-Dividend Date Payout Date  Cash Amount Exchange Symbol  \
# 0        2021-03-10  2021-04-01      0.29125      TSX      T
# 1        2020-12-09  2021-01-01      0.29125      TSX      T
# 2        2020-09-09  2020-10-01      0.29125      TSX      T
# 3        2020-06-09  2020-07-02      0.29125      TSX      T
# 4        2020-03-10  2020-04-01      0.29125      TSX      T
# ..              ...         ...          ...      ...    ...
# 66       2004-09-08  2004-10-04      0.03750      TSX      T
# 67       2004-06-08  2004-07-03      0.03750      TSX      T
# 68       2004-03-09  2004-04-03      0.03750      TSX      T
# 69       2003-12-09  2004-01-03      0.03750      TSX      T
# 70       2003-09-08  2003-10-02      0.03750      TSX      T
#
#     ex-div date epoch  payout date epoch
# 0       1615352400000      1617249600000
# 1       1607490000000      1609477200000
# 2       1599624000000      1601524800000
# 3       1591675200000      1593662400000
# 4       1583812800000      1585713600000
# ..                ...                ...
# 66      1094616000000      1096862400000
# 67      1086667200000      1088827200000
# 68      1078808400000      1080968400000
# 69      1070946000000      1073106000000
# 70      1062993600000      1065067200000
#
# [71 rows x 7 columns]

# %%
print(dfs2)
# Out:
#             Date   Open   High    Low  Close  Adj Close   Volume  Dividends  \
# 0     1995-01-12   5.94   5.94   5.84   5.91       2.14   394400        0.0
# 1     1995-01-13   5.94   5.94   5.78   5.81       2.10    76000        0.0
# 2     1995-01-16   5.81   5.84   5.78   5.81       2.10    70400        0.0
# 3     1995-01-17   5.78   5.78   5.69   5.75       2.08   112400        0.0
# 4     1995-01-18   5.69   5.72   5.69   5.69       2.06    60800        0.0
# ...          ...    ...    ...    ...    ...        ...      ...        ...
# 6445  2020-09-01  24.06  24.17  23.74  24.14      24.14  2262100        0.0
# 6446  2020-09-02  24.16  24.74  24.16  24.60      24.60  2593000        0.0
# 6447  2020-09-03  24.64  24.71  24.00  24.07      24.07  3548600        0.0
# 6448  2020-09-04  24.12  24.28  23.76  23.80      23.80  2442400        0.0
# 6449  2020-09-08  23.89  23.98  23.65  23.90      23.90  2225700        0.0
#
#       Stock Splits symbol market     date_epoch
# 0              0.0      T    TSX   789868800000
# 1              0.0      T    TSX   789955200000
# 2              0.0      T    TSX   790214400000
# 3              0.0      T    TSX   790300800000
# 4              0.0      T    TSX   790387200000
# ...            ...    ...    ...            ...
# 6445           0.0      T    TSX  1598918400000
# 6446           0.0      T    TSX  1599004800000
# 6447           0.0      T    TSX  1599091200000
# 6448           0.0      T    TSX  1599177600000
# 6449           0.0      T    TSX  1599523200000
#
# [6450 rows x 12 columns]

# %%
dfs.rename(columns={'Ex-Dividend Date':'Date'}, inplace=True)
result = pd.merge(dfs, dfs2, on=['Date'], how='outer')
result.sort_values(by='Date', inplace=True)



result.fillna(method='ffill', inplace=True)
#result.fillna(method='bfill', inplace=True)

print(dfs.columns)
print(dfs2.columns)
result.drop(columns=['Close', 'High', 'Low', 'Dividends', 'symbol', 'market', 'date_epoch'], inplace=True)
print(result.columns)
print(result.loc[5])
print(result.loc[21])
print(result)
# Out:
# Index(['Date', 'Payout Date', 'Cash Amount', 'Exchange', 'Symbol',
#        'ex-div date epoch', 'payout date epoch'],
#       dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'symbol', 'market', 'date_epoch'],
#       dtype='object')
# Index(['Date', 'Payout Date', 'Cash Amount', 'Exchange', 'Symbol',
#        'ex-div date epoch', 'payout date epoch', 'Open', 'Adj Close', 'Volume',
#        'Stock Splits'],
#       dtype='object')
# Date                  2019-12-10
# Payout Date           2020-01-02
# Cash Amount              0.29125
# Exchange                     TSX
# Symbol                         T
# ex-div date epoch    1.57595e+12
# payout date epoch    1.57794e+12
# Open                       25.28
# Adj Close                  24.52
# Volume                3.1384e+06
# Stock Splits                   0
# Name: 5, dtype: object
# Date                  2015-12-09
# Payout Date           2016-01-04
# Cash Amount                 0.22
# Exchange                     TSX
# Symbol                         T
# ex-div date epoch    1.44964e+12
# payout date epoch    1.45188e+12
# Open                       20.16
# Adj Close                  16.22
# Volume                4.3278e+06
# Stock Splits                   0
# Name: 21, dtype: object
#             Date Payout Date  Cash Amount Exchange Symbol  ex-div date epoch  \
# 71    1995-01-12         NaN          NaN      NaN    NaN                NaN
# 72    1995-01-13         NaN          NaN      NaN    NaN                NaN
# 73    1995-01-16         NaN          NaN      NaN    NaN                NaN
# 74    1995-01-17         NaN          NaN      NaN    NaN                NaN
# 75    1995-01-18         NaN          NaN      NaN    NaN                NaN
# ...          ...         ...          ...      ...    ...                ...
# 6451  2020-09-04  2020-07-02      0.29125      TSX      T       1.591675e+12
# 6452  2020-09-08  2020-07-02      0.29125      TSX      T       1.591675e+12
# 2     2020-09-09  2020-10-01      0.29125      TSX      T       1.599624e+12
# 1     2020-12-09  2021-01-01      0.29125      TSX      T       1.607490e+12
# 0     2021-03-10  2021-04-01      0.29125      TSX      T       1.615352e+12
#
#       payout date epoch   Open  Adj Close     Volume  Stock Splits
# 71                  NaN   5.94       2.14   394400.0           0.0
# 72                  NaN   5.94       2.10    76000.0           0.0
# 73                  NaN   5.81       2.10    70400.0           0.0
# 74                  NaN   5.78       2.08   112400.0           0.0
# 75                  NaN   5.69       2.06    60800.0           0.0
# ...                 ...    ...        ...        ...           ...
# 6451       1.593662e+12  24.12      23.80  2442400.0           0.0
# 6452       1.593662e+12  23.89      23.90  2225700.0           0.0
# 2          1.601525e+12  23.89      23.90  2225700.0           0.0
# 1          1.609477e+12  23.89      23.90  2225700.0           0.0
# 0          1.617250e+12  23.89      23.90  2225700.0           0.0
#
# [6453 rows x 11 columns]

# %%
# need frequency
# first go does not account for change in frequency for single stocks

dfs3 = pd.read_csv(f'.././datasets/weekly_divhistory_reports/CAN/div_history_report-CAN-2020-08-14.csv', keep_default_na=False)

print(dfs3.head())

# create frequency lookup table
dfs3.drop(columns=["Name", "Price", "Yld", "Ex-Div", "PayRto", "PE", "PB", "Beta", "Mkt Cap", "WK%", "MO%", "2MO%", "3MO%", "6MO%", "1YR%", "report_date_epoch", "ex_div_epoch"], inplace=True)

print(dfs3)

# pull frequency from table

freq = dfs3.loc[dfs3['Symbol']=='T']
print(freq)
# Out:
#   Symbol                          Name   Price   Yld      Ex-Div PayRto  \
# 0    NGT  Newmont Goldcorp Corporation   84.68  1.58  2020-09-09      -
# 1    ABX      Barrick Gold Corporation   35.79  1.19  2020-08-28   12.9
# 2    FNV     Franco-Nevada Corporation  195.62  0.70  2020-09-09   97.8
# 3    WPM       Wheaton Precious Metals   67.01  0.79  2020-08-26  139.7
# 4    NTR                       Nutrien   50.93  4.71  2020-09-29  124.9
#
#        PE     PB  Beta  Mkt Cap   WK%    MO%   2MO%   3MO%   6MO%   1YR%  \
# 0       -   2.30  0.49    68.00 -8.05  -0.79   9.48 -11.27  45.17  65.39
# 1   10.50   2.17  0.31    63.64 -7.18  -3.48   7.64  -9.53  37.02  46.80
# 2  135.50  5.523  0.58    37.28 -4.85  -4.00   9.29  -7.86  27.71  58.91
# 3  174.10  4.309  0.69    30.04 -5.34   2.43  18.08   4.17  68.58  90.64
# 4   26.60  0.956  0.61    28.99  7.33  13.00   4.75  13.94  -6.82 -22.96
#
#    report_date_epoch div_freq market   ex_div_epoch
# 0      1597377600000        Q    CAN  1599624000000
# 1      1597377600000        Q    CAN  1598587200000
# 2      1597377600000        Q    CAN  1599624000000
# 3      1597377600000        Q    CAN  1598414400000
# 4      1597377600000        Q    CAN  1601352000000
#     Symbol div_freq market
# 0      NGT        Q    CAN
# 1      ABX        Q    CAN
# 2      FNV        Q    CAN
# 3      WPM        Q    CAN
# 4      NTR        Q    CAN
# ..     ...      ...    ...
# 394  CUP.U        Q    CAN
# 395    ATP        -    CAN
# 396    PIF        Q    CAN
# 397     JE        -    CAN
# 398    CFY        -    CAN
#
# [399 rows x 3 columns]
#    Symbol div_freq market
# 48      T        Q    CAN

# %%
# got freq now calculate yield for all prices
factor = 0

if (freq.iloc[0]['div_freq'] == 'Q'):
    factor = 4
print(factor)
# Out:
# 4

# %%
# iterate through results and add div yield for each row
# daily_yield = factor*result[Cash Amount]/result[Close]

#for index, row in result.iterrows():
    #print(index)
    #print(row)
    #daily_yield = factor*result.iloc[index]['Cash Amount']/result.iloc[index]['Close']
result['Daily Yield'] = factor*result['Cash Amount']/result['Open']
print(result[3500:4000]['Open'])
# Out:
# 3550     9.09
# 3551     9.15
# 3552     9.11
# 49       9.18
# 3553     9.19
#         ...
# 4037    11.76
# 4038    11.68
# 4039    11.70
# 4040    11.74
# 4041    11.69
# Name: Open, Length: 500, dtype: float64

# %%
print(result.columns)
result = result[result['Daily Yield'].notna()]
#print(subset)
# Out:
# Index(['Date', 'Payout Date', 'Cash Amount', 'Exchange', 'Symbol',
#        'ex-div date epoch', 'payout date epoch', 'Open', 'Adj Close', 'Volume',
#        'Stock Splits', 'Daily Yield'],
#       dtype='object')

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_
59, 11.66, 11.5, 11.5, 11.52, 11.84, 11.96, 12.06, 12.0, 12.25, 11.99, 12.12, 12.07, 11.84, 11.76, 12.14, 12.0, 11.73, 11.69, 11.26, 11.38, 11.5, 11.27, 11.36, 11.24, 11.12, 11.16, 11.21, 11.2, 11.42, 11.21, 11.16, 11.06, 11.3, 11.18, 11.12, 10.95, 10.77, 10.79, 10.99, 11.12, 11.21, 11.01, 11.03, 11.04, 10.94, 10.81, 10.71, 11.04, 11.09, 11.52, 11.55, 11.5, 11.66, 11.7, 11.74, 11.91, 11.8, 11. ...

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objects as go
import cufflinks as cf
init_notebook_mode(connected=True)

trace = go.Scatter(x = result['Date'], y=result['Open'], text = result['Open'], mode='markers')
data=[trace]

layout = go.Layout(title="Cash Amount over time", xaxis=dict(title='Date'), yaxis=dict(title='Amount'), hovermode='closest')

figure = go.Figure(data=data, layout=layout)
iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="5e873785-0164-42d0-9702-ffde4dbbc5b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5e873785-0164-42d0-9702-ffde4dbbc5b9")) {
#                     Plotly.newPlot(
#                         '5e873785-0164-42d0-9702-ffde4dbbc5b9',
#                         [{"mode": "markers", "text": [6.46, 6.47, 6.49, 6.43, 6.34, 6.44, 6.38, 6.31, 6.31, 6.4, 6.22, 6.12, 6.25, 6.38, 6.3, 6.19, 6.03, 5.79, 6.01, 6.06, 6.12, 6.03, 5.94, 5.87, 5.88, 5.93, 6.04, 6.01, 6.12, 6.19, 6.18, 6.26, 5.99, 5.87, 6.12, 6.1, 6.03, 6.12, 6.32, 6.29, 6.23, 6.25, 6.14, 6.11, 6.07, 6.19, 6.15, 6.14, 6.09, 6.13, 6.14, 6.17, 6.21, 6.26, 6.26, 6.3, 6.35, 6.26, 6.26, 6.26, 6.26, 6.3, 6.36, 6.38, 6.4, 6.41, 6.44, 6.47, 6.47, 6.53, 6.55, 6.54, 6.51, 6.5, 6.49, 6.47, 6.45, 6.5, 6.49, 6.44, 6.44, 6.49, 6.74, 6.91, 6.89, 6.94, 6.8, 6.7, 6.77, 6.7, 6.57, 6.68, 6.64, 6.59, 6.6, 6.7, 6.78, 6.78, 6.65, 6.5, 6.56, 6.33, 6.41, 6.75, 6.78, 6.7, 6.72, 6.76, 6.69, 6.71, 6.68, 6.65, 6.53, 6.64, 6.56, 6.53, 6.48, 6.45, 6.41, 6.39, 6.33, 6.42, 6.38, 6.16, 6.15, 6.39, 6.47, 6.49, 6.34, 6.19, 6.01, 6.14, 6.29, 6.24, 6.12, 6.13, 6.0, 5.84, 5.91, 5.85, 5.94, 6.05, 5.97, 5.89, 5.87, 5.84, 5.97, 5.94, 5.95, 5.97, 5.94, 5.81, 5.86, 5.66, 5.65, 5.76, 5.79, 5.7, 5.67, 5.81, 5.89, 5.93, 5.97, 5.85, 5.8, 5.79, 5.85, 6.0, 6.14, 6.2, 6.25, 6.17, 6.06, 6.05, 5.93, 5.81, 5.88, 5.85, 5.9, 5.95, 5.89, 5.84, 5.8, 5.74, 5.9, 5.86, 5.78, 5.84, 5.68, 5.78, 5.75, 5.75, 5.66, 5.56, 5.53, 
51, 11.5, 11.48, 11.57, 11.65, 11.84, 11.97, 11.88, 11.98, 11.89, 11.85, 12.04, 12.47, 12.09, 12.28, 11.9, 11.89, 12.14, 12.08, 12.05, 11.69, 11.52, 11.99, 12.05, 11.93, 11.96, 11.75, 11.74, 11.73, 11.4, 11.3, 11.31, 11.7, 11.7, 11.55, 11.59, 11.36, 11.36, 11.45, 11.4, 11.14, 11.45, 11.65, 11.3, 11.5, 11.43, 11.88, 12.09, 11.68, 11.44, 11.5, 11.46, 11.05, 10.86, 11.11, 11.41, 11.27, 11.36, 11.15, 11.21, 10.96, 10.91, 10.8, 10.74, 10.9, 10.88, 11.19, 11.05, 11.12, 11.18, 11.48, 11.59, 11.66, 11.5, 11.5, 11.52, 11.84, 11.96, 12.06, 12.0, 12.25, 11.99, 12.12, 12.07, 11.84, 11.76, 12.14, 12.0, 11.73, 11.69, 11.26, 11.38, 11.5, 11.27, 11.36, 11.24, 11.12, 11.16, 11.21, 11.2, 11.42, 11.21, 11.16, 11.06, 11.3, 11.18, 11.12, 10.95, 10.77, 10.79, 10.99, 11.12, 11.21, 11.01, 11.03, 11.04, 10.94, 10.81, 10.71, 11.04, 11.09, 11.52, 11.55, 11.5, 11.66, 11.7, 11.74, 11.91, 11.8, 11. ...

# %%
# pi chart of all divdidend frequencies

lab = dfs3['div_freq'].value_counts().keys().tolist()
val = dfs3['div_freq'].value_counts().values.tolist()

trace = go.Pie(labels=lab, values=val, marker=dict(colors=['red']), hoverinfo='value')
data = [trace]

layout = go.Layout(title='Dividend Payout Frequencies Canada')

fig = go.Figure(data = data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="04cd31ff-9fc1-4c0a-9419-5a09afcfcf00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("04cd31ff-9fc1-4c0a-9419-5a09afcfcf00")) {
#                     Plotly.newPlot(
#                         '04cd31ff-9fc1-4c0a-9419-5a09afcfcf00',
#                         [{"hoverinfo": "value", "labels": ["Q", "-", "M", "S", "A"], "marker": {"colors": ["red"]}, "type": "pie", "values": [188, 103, 97, 9, 2]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
# pi chart of all divdidend frequencies
dfs4 = pd.read_csv(f'.././datasets/weekly_divhistory_reports/USA/div_history_report-USA-2020-08-14.csv', keep_default_na=False)

# create frequency lookup table
dfs4.drop(columns=["Name", "Price", "Yld", "Ex-Div", "PayRto", "PE", "PB", "Beta", "Mkt Cap", "WK%", "MO%", "2MO%", "3MO%", "6MO%", "1YR%", "report_date_epoch", "ex_div_epoch"], inplace=True)




lab = dfs4['div_freq'].value_counts().keys().tolist()
val = dfs4['div_freq'].value_counts().values.tolist()

trace = go.Pie(labels=lab, values=val, marker=dict(colors=['red']), hoverinfo='value')
data = [trace]

layout = go.Layout(title='Dividend Payout Frequencies United States')

fig = go.Figure(data = data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="cba2480f-5f02-4314-810f-40454d2dd651" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cba2480f-5f02-4314-810f-40454d2dd651")) {
#                     Plotly.newPlot(
#                         'cba2480f-5f02-4314-810f-40454d2dd651',
#                         [{"hoverinfo": "value", "labels": ["Q", "-", "S", "M", "A", "U"], "marker": {"colors": ["red"]}, "type": "pie", "values": [882, 151, 43, 28, 15, 3]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
# no optimization 

from scipy.signal import find_peaks
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import matplotlib.pyplot as plt
import decimal

dfs5 = pd.read_csv('../datasets/yield_history/yield_history_nyse_AZZ.csv')
#print(dfs5)

value_array = dfs5['Daily Yield']
date_array = dfs5['Date']
#print(value_array)
peaks = find_peaks(value_array, prominence=0.004)[0]
valleys = find_peaks(-value_array, prominence=0.004)[0]
#print(type(peaks))
print(peaks)
fig = go.Figure()
fig.add_trace(go.Scatter(
    y=value_array,
    mode='lines+markers',
    name='Original Plot'
))

fig.add_trace(go.Scatter(
    x=peaks,
    y=[value_array[j] for j in peaks],
    mode='markers',
    marker=dict(
        size=8,
        color='red',
        symbol='cross'
    ),
    name='Detected Peaks'
))

fig.add_trace(go.Scatter(
    x=valleys,
    y=[value_array[j] for j in valleys],
    mode='markers',
    marker=dict(
        size=8,
        color='green',
        symbol='cross'
    ),
    name='Detected Valleys'
))

#fig.update_xaxes(date_array)

fig.show()

total = 0 
for temp in peaks:
    #print(f"Value: {value_array[temp]} Index: {temp}")
    total += value_array[temp]
    
peak_avg = total/len(peaks)
print(f"Peak average value (total data set) {peak_avg}")

total =0 
for temp in valleys:
    total += value_array[temp] 
    
valley_avg = total/len(valleys)
print(f"Vally average value (total data set) {valley_avg}")
# Out:
# [  18   21   79   82   84   87  130  141  203  348  476  506  509  514
#   519  587  663  667  691  694  702  706  724  731  740  753  757  795
#   802  805  809  813  817  820  841  890  894  941  965  968  970 1253
#  1259 1265 1270 1273 1405 1471 1476 1479 1486 1493 1568 1579 1664 1741
#  1853 1856 2045 2076 2140 2173 2192 2218 2266 2318 2345 2368 2439 2516
#  2567 2590 2600 2602 2656 2686 2738 2860 2954 3072 3225 3272 3341 3344
#  3346 3416 3467 3500 3503 3505 3507 3627 3727 3859 4002 4148 4329 4460
#  4514 4765 4836 5066 5151 5306 5446 5485 5523 5927 6311 7149 7303 7612
#  7690]
# <div>
#
#
#             <div id="27635624-d409-4d14-aef9-ddff7433bf78" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27635624-d409-4d14-aef9-ddff7433bf78")) {
#                     Plotly.newPlot(
#                         '27635624-d409-4d14-aef9-ddff7433bf78',
#                         [{"mode": "lines+markers", "name": "Original Plot", "type": "scatter", "y": [0.01631654676258993, 0.016676470588235296, 0.017446153846153847, 0.01905882352941177, 0.01905882352941177, 0.01859016393442623, 0.01905882352941177, 0.01905882352941177, 0.01955172413793104, 0.020070796460177, 0.020070796460177, 0.020070796460177, 0.020070796460177, 0.01955172413793104, 0.020070796460177, 0.020070796460177, 0.022235294117647058, 0.02290909090909091, 0.02492307692307693, 0.023625000000000004, 0.02492307692307693, 0.02492307692307693, 0.02492307692307693, 0.02412765957446809, 0.022235294117647058, 0.02290909090909091, 0.023625000000000004, 0.023625000000000004, 0.022235294117647058, 0.023625000000000004, 0.02290909090909091, 0.023625000000000004, 0.0216, 0.021, 0.021, 0.01955172413793104, 0.020070796460177, 0.017446153846153847, 0.018144, 0.018144, 0.017718750000000002, 0.01859016393442623, 0.018144, 0.018144, 0.01859016393442623, 0.01905882352941177, 0.020432432432432437, 0.020070796460
# Value: 0.07619047619047617 Index: 3341
# Value: 0.07619047619047617 Index: 3344
# Value: 0.07619047619047617 Index: 3346
# Value: 0.05925925925925925 Index: 3416
# Value: 0.05947955390334572 Index: 3467
# Value: 0.05280528052805281 Index: 3500
# Value: 0.05280528052805281 Index: 3503
# Value: 0.05280528052805281 Index: 3505
# Value: 0.05280528052805281 Index: 3507
# Value: 0.0449438202247191 Index: 3627
# Value: 0.04776119402985075 Index: 3727
# Value: 0.04289544235924933 Index: 3859
# Value: 0.03950617283950617 Index: 4002
# Value: 0.0299625468164794 Index: 4148
# Value: 0.01689545934530095 Index: 4329
# Value: 0.012738853503184712 Index: 4460
# Value: 0.012698412698412698 Index: 4514
# Value: 0.019512195121951226 Index: 4765
# Value: 0.018867924528301886 Index: 4836
# Value: 0.034722222222222224 Index: 5066
# Value: 0.029222676797194626 Index: 5151
# Value: 0.027609055770292656 Index: 5306
# Value: 0.02465483234714004 Index: 5446
# Value: 0.02646903123345685 Index: 5485
# Value: 0.026301946344029457 Index: 5523
# Value: 0.01585952987822147 Index: 5927
# Value: 0.015432098765432096 Index: 6311
# Value: 0.017171717171717168 Index: 7149
# Value: 0.01804192093393473 Index: 7303
# Value: 0.03296170625302957 Index: 7612
# Value: 0.023767913317022018 Index: 7690
# 113
# 4.057177836272881209928042876
# Peak average value (total data set) 0.03590422863958301955688533519
# Vally average value (total data set) 0.028328209875366904

# %%
# last 10 year

from scipy.signal import find_peaks
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import matplotlib.pyplot as plt

dfs5 = pd.read_csv('../datasets/yield_history/yield_history_tsx_BDT.csv')
#print(dfs5)


# mask in all items after Jan 1 2010
dfs5['Date'] = pd.to_datetime(dfs5['Date'])
start_date = '01-01-2010'
mask = dfs5['Date']> start_date
new_df=dfs5.loc[mask]

# need to reset index because find_peak uses a 0 start sequential indexing scheme
new_df = new_df.reset_index(drop=True)
#print(new_df)

value_array = new_df['Daily Yield']
date_array = new_df['Date']
print(value_array)
peaks = find_peaks(value_array, prominence=0.004)[0]
valleys = find_peaks(-value_array, prominence=0.004)[0]


#print(type(peaks))
print(peaks)
fig = go.Figure()
fig.add_trace(go.Scatter(
    y=value_array,
    mode='lines+markers',
    name='Original Plot'
))

fig.add_trace(go.Scatter(
    x=peaks,
    y=[value_array[j] for j in peaks],
    mode='markers',
    marker=dict(
        size=8,
        color='red',
        symbol='cross'
    ),
    name='Detected Peaks'
))

fig.add_trace(go.Scatter(
    x=valleys,
    y=[value_array[j] for j in valleys],
    mode='markers',
    marker=dict(
        size=8,
        color='green',
        symbol='cross'
    ),
    name='Detected Valleys'
))

fig.show()

total =0 
for temp in peaks:
    total += value_array[temp] 
    
peak_avg = total/len(peaks)
print(f"Peak Average value (10 year dataset) {peak_avg}")

total =0 
for temp in valleys:
    total += value_array[temp] 
    
valley_avg = total/len(valleys)
print(f"Valley Average value (10 year dataset) {valley_avg}")
# Out:
#            Date Payout Date  Cash Amount Exchange Symbol  ex-div date epoch  \
# 0    2010-01-04  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 1    2010-01-05  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 2    2010-01-06  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 3    2010-01-07  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 4    2010-01-08  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# ...         ...         ...          ...      ...    ...                ...
# 2680 2020-09-08  2020-09-18       0.0325      TSX    BDT       1.598587e+12
# 2681 2020-09-29  2020-10-20       0.0325      TSX    BDT       1.601352e+12
# 2682 2020-10-29  2020-11-20       0.0325      TSX    BDT       1.603944e+12
# 2683 2020-11-27  2020-12-19       0.0325      TSX    BDT       1.606453e+12
# 2684 2020-12-29  2021-01-19       0.0325      TSX    BDT       1.609218e+12
#
#       payout date epoch   Open  Adj Close   Volume  Daily Yield
# 0          1.263964e+12  11.45       5.37  39300.0     0.052402
# 1          1.263964e+12  11.33       5.36  14400.0     0.052957
# 2          1.263964e+12  11.35       5.33  27000.0     0.052863
# 3          1.263964e+12  11.33       5.33  28200.0     0.052957
# 4          1.263964e+12  11.33       5.34  37500.0     0.052957
# ...                 ...    ...        ...      ...          ...
# 2680       1.600402e+12   6.44       6.48  32600.0     0.060559
# 2681       1.603166e+12   6.44       6.48  32600.0     0.060559
# 2682       1.605848e+12   6.44       6.48  32600.0     0.060559
# 2683       1.608354e+12   6.44       6.48  32600.0     0.060559
# 2684       1.611032e+12   6.44       6.48  32600.0     0.060559
#
# [2685 rows x 11 columns]
# 0       0.052402
# 1       0.052957
# 2       0.052863
# 3       0.052957
# 4       0.052957
#           ...
# 2680    0.060559
# 2681    0.060559
# 2682    0.060559
# 2683    0.060559
# 2684    0.060559
# Name: Daily Yield, Length: 2685, dtype: float64
# [  20   60   97  127  220  322  360  441  613  670  750  853  919  994
#  1093 1239 1263 1274 1319 1331 1341 1386 1397 1405 1415 1459 1476 1516
#  1571 1681 1721 1761 1803 1866 1908 2067 2106 2138 2158 2177 2212 2220
#  2254 2351 2357 2408 2413 2446 2554 2559 2562 2573 2587 2593 2622 2634
#  2641]
# <div>
#
#
#             <div id="26056003-621b-4656-ac6e-01d2050aa7a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("26056003-621b-4656-ac6e-01d2050aa7a4")) {
#                     Plotly.newPlot(
#                         '26056003-621b-4656-ac6e-01d2050aa7a4',
#                         [{"mode": "lines+markers", "name": "Original Plot", "type": "scatter", "y": [0.05240174672489084, 0.052956751985878216, 0.052863436123348026, 0.052956751985878216, 0.052956751985878216, 0.0530035335689046, 0.052631578947368425, 0.0530035335689046, 0.05376344086021506, 0.05366726296958856, 0.05400540054005402, 0.052631578947368425, 0.052956751985878216, 0.052956751985878216, 0.052956751985878216, 0.054495912806539516, 0.055299539170506916, 0.0560747663551402, 0.05644402634054563, 0.05730659025787966, 0.057915057915057924, 0.05725190839694658, 0.05597014925373135, 0.05628517823639776, 0.05714285714285715, 0.054545454545454564, 0.05681818181818182, 0.05687203791469195, 0.05639097744360904, 0.056603773584905676, 0.055299539170506916, 0.05424954792043401, 0.05376344086021506, 0.05415162454873647, 0.054545454545454564, 0.0554016620498
from scipy.signal import find_peaks
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import matplotlib.pyplot as plt

dfs5 = pd.read_csv('../datasets/yield_history/yield_history_tsx_BDT.csv')
#print(dfs5)


# mask in all items after Jan 1 2010
dfs5['Date'] = pd.to_datetime(dfs5['Date'])
start_date = '01-01-2010'
mask = dfs5['Date']> start_date
new_df=dfs5.loc[mask]

# need to reset index because find_peak uses a 0 start sequential indexing scheme
new_df = new_df.reset_index(drop=True)
print(new_df)

value_array = new_df['Daily Yield']
date_array = new_df['Date']
print(value_array)
peaks = find_peaks(value_array, prominence=0.001)[0]
valleys = find_peaks(-value_array, prominence=0.001)[0]


#print(type(peaks))
print(peaks)
fig = go.Figure()
fig.add_trace(go.Scatter(
    y=value_array,
    mode='lines+markers',
    name='Original Plot'
))

fig.add_trace(go.Scatter(
    x=peaks,
    y=[value_array[j] for j in peaks],
    mode='markers',
    marker=dict(
        size=8,
        color='red',
        symbol='cross'
    ),
    name='Detected Peaks'
))

fig.add_trace(go.Scatter(
    x=valleys,
    y=[value_array[j] for j in valleys],
    mode='markers',
    marker=dict(
        size=8,
        color='green',
        symbol='cross'
    ),
    name='Detected Valleys'
))

fig.show()

total =0 
for temp in peaks:
    total += value_array[temp] 
    
peak_avg = total/len(peaks)
print(f"Peak Average value (10 year dataset) {peak_avg}")

total =0 
for temp in valleys:
    total += value_array[temp] 
    
valley_avg = total/len(valleys)
print(f"Valley Average value (10 year dataset) {valley_avg}")
# Out:
#            Date Payout Date  Cash Amount Exchange Symbol  ex-div date epoch  \
# 0    2010-01-04  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 1    2010-01-05  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 2    2010-01-06  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 3    2010-01-07  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# 4    2010-01-08  2010-01-20       0.0500      TSX    BDT       1.262063e+12
# ...         ...         ...          ...      ...    ...                ...
# 2680 2020-09-08  2020-09-18       0.0325      TSX    BDT       1.598587e+12
# 2681 2020-09-29  2020-10-20       0.0325      TSX    BDT       1.601352e+12
# 2682 2020-10-29  2020-11-20       0.0325      TSX    BDT       1.603944e+12
# 2683 2020-11-27  2020-12-19       0.0325      TSX    BDT       1.606453e+12
# 2684 2020-12-29  2021-01-19       0.0325      TSX    BDT       1.609218e+12
#
#       payout date epoch   Open  Adj Close   Volume  Daily Yield
# 0          1.263964e+12  11.45       5.37  39300.0     0.052402
# 1          1.263964e+12  11.33       5.36  14400.0     0.052957
# 2          1.263964e+12  11.35       5.33  27000.0     0.052863
# 3          1.263964e+12  11.33       5.33  28200.0     0.052957
# 4          1.263964e+12  11.33       5.34  37500.0     0.052957
# ...                 ...    ...        ...      ...          ...
# 2680       1.600402e+12   6.44       6.48  32600.0     0.060559
# 2681       1.603166e+12   6.44       6.48  32600.0     0.060559
# 2682       1.605848e+12   6.44       6.48  32600.0     0.060559
# 2683       1.608354e+12   6.44       6.48  32600.0     0.060559
# 2684       1.611032e+12   6.44       6.48  32600.0     0.060559
